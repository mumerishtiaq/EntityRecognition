# %%
import spacy
from spacy.matcher import Matcher
from spacy import displacy
from collections import Counter
import en_core_web_sm
from bs4 import BeautifulSoup
import requests
import re
import textwrap
nlp = spacy.load("en_core_web_sm")

# %%
#Description and Condition of Storm Drainage!
Description_1 = "Description:  The topography of the site is relatively level, resulting in ongoing issues with adequate drainage to mitigate surface stormwater.  This is especially true in the parking and loading dock lots, located on the east and north sides of the building.  The narrow landscape strip located on the west side of the building is steeply sloped toward the building foundation.  The south side of the site generally drains to the curb‐and‐gutter at the street.  The east site is intended to drain towards two stormwater inlet drains, located in the center of the east‐side paved parking lot.  It is anticipated that the stormwater inlet drains in the parking lot are connected underground to the municipal stormwater system, although no official documentation of this was found.  It appears that the north portion of the site is generally intended to drain to the northeast corner.  No evidence of on‐site water retention or detention was observed."
Condition_1 = "Condition:  The slope of the grading at the east and north sides of the building is inadequate to move water away from the building, resulting in standing water, accelerated aging of pavement, and water entry into the building in some locations."
#Description and Condition of Traffic Control!
Description_2 = 'Description:  Vehicular access to the site is from South Windermere Street on the west, onto the property, via a curb cut located at the southwest corner of the lot.  This curb cut leads directly into the south‐end paved parking lot, and further to the east‐side parking area.  Access to the truck parking and loading dock area on the north side of the building is from West Stanford Avenue, via a curb cut located at the northeast corner of the property.'
Condition_2 = 'Condition:  Vehicular access to the site from the adjacent public streets, and vehicular circulation through the site appeared to be generally adequate, with no issues observed or reported by the on‐site property manager.'
#Description of Parking! Condition not available 
Description_3 = 'Description:  Parking is accommodated on the site in three distinct surface, paved parking areas.  The first is an asphalt‐paved lot located to the immediate south end of the building and adjacent to the main entrance into the administration office.  This lot accommodates 24 car parking stalls*.  One accessible parking space was noted during Marx|Okubos recent visit, which we understand has been reduced from three spaces previously provided. The second surface parking lot is an asphalt‐paved area located adjacent to the east side of the building.  This accommodates 37 car parking stalls* and a dedicated loading zone.  No accessible spaces were observed in this lot. The third surface parking lot is an asphalt‐paved area located adjacent to the north side of the building.  This lot accommodates truck parking and a dedicated loading zone for shipping and receiving.  Based on Marx|Okubos 2016 count, six truck parking stalls, three trailer parking spaces, and five car parking spaces are provided in this area.  No accessible spaces were observed in this lot.  Parking along Windermere Street was also being utilized during Marx|Okubos site visit.'
#Condition of Paving and sidewalks! Description not available
Condition_3 = 'Condition:  The south‐side asphalt‐paved parking area is in fair condition, with acceptable drainage and paving surface, which will require crack seal, seal coat, and re‐striping in the term.  Issues with the slope of the accessible parking space were noted and can be referenced in the Accessibility section of this report. The east parking lot is in poor condition, with potholes, widespread alligator cracking, surface unravelling and flat grades that reportedly allow water into the building in select locations, and otherwise interfere with production.  The north loading lot is in poor condition with potholes, widespread alligator cracking, surface unravelling and flat grades.  A large pothole exists at the north entry drive on the route to the loading dock.  The north lot previously contained a portion of dirt, which was reportedly recently paved. Mill and overlay the existing asphalt paving with selective areas of full‐depth replacement.  Add heavy‐duty asphalt or concrete at tractor trailer circulation paths.  Add trench drains near the perimeter of the building in locations where water enters on the east elevation, and lower the elevation of the inlet in this area if possible.  Considering the flatness of the site, mill and overlay would need to be performed with care given to creating slope away from the building.   It should be understood that this action may require the services of a professional civil engineer to assess grades, and recommend inlet elevations.  Performing an ALTA survey that includes site grade elevations may provide useful information prior to embarking on repairs.The wood strips at the south sidewalks have deteriorated causing depressions at the joints.  From a functional and aesthetic standpoint, these wood strips should be replaced.  This item corresponds to an accessible route nonconformity noted in the Accessibility section.  Cost is considered negligible and the work could be performed by the in‐house staff as part of the repair and maintenance budget.'

# %%
displacy.render(nlp(str(Description_1)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a8bd0bd0cecc4213b62422234d064fd6-0" class="displacy" width="19250" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Description:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
# ...

# %%
displacy.render(nlp(str(Condition_1)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="faa0317c44e440bba7c1dbdbd5ff9ac4-0" class="displacy" width="5090" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Condition:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
# ...

# %% [markdown]
# Description_1(Storm Drainage)

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'NOUN'}, {'POS':'ADV'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Description_1)
doc_adv_noun = nlp_adv_noun(Description_1)
doc_verb_noun = nlp_verb_noun(Description_1)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
DS_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(DS_final)
# Out:
#  ADJ NOUN ongoing issues,
# ADJ NOUN adequate drainage,
# ADJ NOUN narrow landscape,
# ADJ NOUN south side,
# ADJ NOUN municipal stormwater,
# ADJ NOUN official documentation,
# ADJ NOUN north portion,
# ADJ NOUN northeast corner,
#  VERB NOUN mitigate surface,
# VERB NOUN loading dock,
# VERB NOUN paved parking,
#  ADV NOUN site generally,

# %%
import pandas as pd
  
data1 = DS_final
df_ds_final = pd.DataFrame([x.split(':') for x in data1.split('\n')])
print(df_ds_final)
# Out:
#                                    0
# 0           ADJ NOUN ongoing issues,
# 1        ADJ NOUN adequate drainage,
# 2         ADJ NOUN narrow landscape,
# 3               ADJ NOUN south side,
# 4     ADJ NOUN municipal stormwater,
# 5   ADJ NOUN official documentation,
# 6            ADJ NOUN north portion,
# 7         ADJ NOUN northeast corner,
# 8        VERB NOUN mitigate surface,
# 9            VERB NOUN loading dock,
# 10          VERB NOUN paved parking,
# 11          ADV NOUN site generally,
# 12

# %% [markdown]
# Condition_1(Storm Drainage)!

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'NOUN'}, {'POS':'ADV'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_1)
doc_adv_noun = nlp_adv_noun(Condition_1)
doc_verb_noun = nlp_verb_noun(Condition_1)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
DS_Cond_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(DS_Cond_final)
# Out:
#   VERB NOUN move water,
# VERB NOUN standing water,
# VERB NOUN accelerated aging,
#  ADV NOUN water away,

# %%
import pandas as pd
  
data2 = DS_Cond_final
df_ds_cond_final = pd.DataFrame([x.split(':') for x in data2.split('\n')])
print(df_ds_cond_final)
# Out:
#                               0
# 0         VERB NOUN move water,
# 1     VERB NOUN standing water,
# 2  VERB NOUN accelerated aging,
# 3          ADV NOUN water away,
# 4

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'NOUN'}, {'POS':'ADV'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_1)
doc_adv_noun = nlp_adv_noun(Condition_1)
doc_verb_noun = nlp_verb_noun(Condition_1)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("ADJ NOUN", span.text)


for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("VERB NOUN", span.text)

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    print("ADV NOUN", span.text)
# Out:
# VERB NOUN move water
# VERB NOUN standing water
# VERB NOUN accelerated aging
# ADV NOUN water away

# %% [markdown]
# Description_2(Traffic Control)!

# %%
displacy.render(nlp(str(Description_2)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1ede85747d5c43799598750b473d03f4-0" class="displacy" width="19130" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Description:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
# ...

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Description_2)
doc_adv_noun = nlp_adv_noun(Description_2)
doc_verb_noun = nlp_verb_noun(Description_2)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
TC_Des_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(TC_Des_final)
# Out:
#  ADJ NOUN Vehicular access,
# ADJ NOUN northeast corner,
#  VERB NOUN cut leads,
# VERB NOUN paved parking,
# VERB NOUN east‐side parking,

# %%
import pandas as pd
  
data3 = TC_Des_final
df_TC_Des_final = pd.DataFrame([x.split(':') for x in data3.split('\n')])
print(df_TC_Des_final)
# Out:
#                               0
# 0    ADJ NOUN Vehicular access,
# 1    ADJ NOUN northeast corner,
# 2          VERB NOUN cut leads,
# 3      VERB NOUN paved parking,
# 4  VERB NOUN east‐side parking,
# 5

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Description_2)
doc_adv_noun = nlp_adv_noun(Description_2)
doc_verb_noun = nlp_verb_noun(Description_2)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("ADJ NOUN", span.text)


for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("VERB NOUN", span.text)

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    print("ADV NOUN", span.text)
# Out:
# ADJ NOUN Vehicular access
# ADJ NOUN northeast corner
# VERB NOUN cut leads
# VERB NOUN paved parking
# VERB NOUN east‐side parking

# %% [markdown]
# Condition_2(Traffic Control)

# %%
displacy.render(nlp(str(Condition_2)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ae01ffe90dda4d98b204deb7a1d418ba-0" class="displacy" width="7850" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Condition:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
# ...

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_2)
doc_adv_noun = nlp_adv_noun(Condition_2)
doc_verb_noun = nlp_verb_noun(Condition_2)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
TC_Cond_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(TC_Cond_final)
# Out:
#  ADJ NOUN Vehicular access,
# ADJ NOUN public streets,
# ADJ NOUN vehicular circulation,

# %%
import pandas as pd
  
data4 = TC_Cond_final
df_TC_cond_final = pd.DataFrame([x.split(':') for x in data4.split('\n')])
print(df_TC_cond_final)
# Out:
#                                  0
# 0       ADJ NOUN Vehicular access,
# 1         ADJ NOUN public streets,
# 2  ADJ NOUN vehicular circulation,
# 3

# %%
nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_2)
doc_adv_noun = nlp_adv_noun(Condition_2)
doc_verb_noun = nlp_verb_noun(Condition_2)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("ADJ NOUN", span.text)


for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("VERB NOUN", span.text)

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    print("ADV NOUN", span.text)
# Out:
# ADJ NOUN Vehicular access
# ADJ NOUN public streets
# ADJ NOUN vehicular circulation

# %% [markdown]
# Description_3(Parking)

# %%
displacy.render(nlp(str(Description_3)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="47640f8065b546a5a8e76df8481dfa66-0" class="displacy" width="42890" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Description:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
# ...

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Description_3)
doc_adv_noun = nlp_adv_noun(Description_3)
doc_verb_noun = nlp_verb_noun(Description_3)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
Park_Des_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(Park_Des_final)
# Out:
#  ADJ NOUN distinct surface,
# ADJ NOUN south end,
# ADJ NOUN main entrance,
# ADJ NOUN accessible parking,
# ADJ NOUN recent visit,
# ADJ NOUN second surface,
# ADJ NOUN accessible spaces,
# ADJ NOUN third surface,
# ADJ NOUN accessible spaces,
#  VERB NOUN paved parking,
# VERB NOUN asphalt‐paved lot,
# VERB NOUN asphalt‐paved area,
# VERB NOUN dedicated loading,
# VERB NOUN asphalt‐paved area,
# VERB NOUN accommodates truck,
# VERB NOUN dedicated loading,
#  ADV NOUN previously provided,

# %%
import pandas as pd
  
data5 = Park_Des_final
df_Park_Des_final = pd.DataFrame([x.split(':') for x in data5.split('\n')])
print(df_Park_Des_final)
# Out:
#                                  0
# 0       ADJ NOUN distinct surface,
# 1              ADJ NOUN south end,
# 2          ADJ NOUN main entrance,
# 3     ADJ NOUN accessible parking,
# 4           ADJ NOUN recent visit,
# 5         ADJ NOUN second surface,
# 6      ADJ NOUN accessible spaces,
# 7          ADJ NOUN third surface,
# 8      ADJ NOUN accessible spaces,
# 9         VERB NOUN paved parking,
# 10    VERB NOUN asphalt‐paved lot,
# 11   VERB NOUN asphalt‐paved area,
# 12    VERB NOUN dedicated loading,
# 13   VERB NOUN asphalt‐paved area,
# 14   VERB NOUN accommodates truck,
# 15    VERB NOUN dedicated loading,
# 16   ADV NOUN previously provided,
# 17

# %%
nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Description_3)
doc_adv_noun = nlp_adv_noun(Description_3)
doc_verb_noun = nlp_verb_noun(Description_3)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("ADJ NOUN", span.text)


for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("VERB NOUN", span.text)

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    print("ADV NOUN", span.text)
# Out:
# ADJ NOUN distinct surface
# ADJ NOUN south end
# ADJ NOUN main entrance
# ADJ NOUN accessible parking
# ADJ NOUN recent visit
# ADJ NOUN second surface
# ADJ NOUN accessible spaces
# ADJ NOUN third surface
# ADJ NOUN accessible spaces
# VERB NOUN paved parking
# VERB NOUN asphalt‐paved lot
# VERB NOUN asphalt‐paved area
# VERB NOUN dedicated loading
# VERB NOUN asphalt‐paved area
# VERB NOUN accommodates truck
# VERB NOUN dedicated loading
# ADV NOUN previously provided

# %% [markdown]
# Condition_3(Paving and Sidewalks)

# %%
displacy.render(nlp(str(Condition_3)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="96dafd4276e4401ab17bb21c9a64b2c2-0" class="displacy" width="74210" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Condition:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
# ...

# %%
import spacy
from spacy.matcher import Matcher

nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_3)
doc_adv_noun = nlp_adv_noun(Condition_3)
doc_verb_noun = nlp_verb_noun(Condition_3)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

ds_adj_noun = []
ds_adj_noun_final = ' '


for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    #print("ADJ NOUN",match_id, string_id, start, end, span.text,',')
    DS_Adj_noun = "ADJ NOUN " + span.text
    ds_adj_noun.append(DS_Adj_noun)
for x in ds_adj_noun:
  adj_noun = x+','
  ds_adj_noun_final += adj_noun+'\n'
  #print(keyword)

ds_verb_noun = []
ds_verb_noun_final = ' '

for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    DS_Verb_noun = "VERB NOUN " + span.text
    ds_verb_noun.append(DS_Verb_noun)
for x in ds_verb_noun:
  verb_noun = x+','
  ds_verb_noun_final += verb_noun+'\n'

ds_adv_noun = []
ds_adv_noun_final = ' '

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    DS_Adv_noun = "ADV NOUN " + span.text
    ds_adv_noun.append(DS_Adv_noun)
for x in ds_adv_noun:
  adv_noun = x+','
  ds_adv_noun_final += adv_noun+'\n'
SW_Cond_final = ds_adj_noun_final + ds_verb_noun_final + ds_adv_noun_final
print(SW_Cond_final)
# Out:
#  ADJ NOUN asphalt‐paved parking,
# ADJ NOUN fair condition,
# ADJ NOUN acceptable drainage,
# ADJ NOUN accessible parking,
# ADJ NOUN poor condition,
# ADJ NOUN widespread alligator,
# ADJ NOUN flat grades,
# ADJ NOUN select locations,
# ADJ NOUN poor condition,
# ADJ NOUN widespread alligator,
# ADJ NOUN flat grades,
# ADJ NOUN large pothole,
# ADJ NOUN selective areas,
# ADJ NOUN civil engineer,
# ADJ NOUN useful information,
# ADJ NOUN aesthetic standpoint,
# ADJ NOUN accessible route,
#  VERB NOUN paving surface,
# VERB NOUN require crack,
# VERB NOUN allow water,
# VERB NOUN existing asphalt,
# VERB NOUN Add trench,
# VERB NOUN creating slope,
# VERB NOUN assess grades,
# VERB NOUN recommend inlet,
# VERB NOUN includes site,
# VERB NOUN causing depressions,
#  ADV NOUN reportedly allow,
# ADV NOUN otherwise interfere,
# ADV NOUN previously contained,
# ADV NOUN recently paved,

# %%
import pandas as pd
  
data6 = SW_Cond_final
df_SW_Cond_final = pd.DataFrame([x.split(':') for x in data6.split('\n')])
print(df_SW_Cond_final)
# Out:
#                                    0
# 0    ADJ NOUN asphalt‐paved parking,
# 1           ADJ NOUN fair condition,
# 2      ADJ NOUN acceptable drainage,
# 3       ADJ NOUN accessible parking,
# 4           ADJ NOUN poor condition,
# 5     ADJ NOUN widespread alligator,
# 6              ADJ NOUN flat grades,
# 7         ADJ NOUN select locations,
# 8           ADJ NOUN poor condition,
# 9     ADJ NOUN widespread alligator,
# 10             ADJ NOUN flat grades,
# 11           ADJ NOUN large pothole,
# 12         ADJ NOUN selective areas,
# 13          ADJ NOUN civil engineer,
# 14      ADJ NOUN useful information,
# 15    ADJ NOUN aesthetic standpoint,
# 16        ADJ NOUN accessible route,
# 17         VERB NOUN paving surface,
# 18          VERB NOUN require crack,
# 19            VERB NOUN allow water,
# 20       VERB NOUN existing asphalt,
# 21             VERB NOUN Add trench,
# 22         VERB NOUN creating slope,
# 23          VERB NOUN assess grades,
# ...

# %%
import spacy
from spacy.matcher import Matcher
nlp_adj_noun = spacy.load("en_core_web_sm")
nlp_verb_noun = spacy.load("en_core_web_sm")
nlp_adv_noun = spacy.load("en_core_web_sm")

matcher_adj_noun = Matcher(nlp_adj_noun.vocab)
matcher_verb_noun = Matcher(nlp_verb_noun.vocab)
matcher_adv_noun = Matcher(nlp_adv_noun.vocab)

patterns_adj_noun = [
    [{'POS':'ADJ'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_verb_noun = [
    [{'POS':'VERB'}, {'POS': 'SPACE'}, {'POS':'NOUN'}],
    ]
patterns_adv_noun = [
    [{'POS':'ADV'}, {'POS': 'SPACE'}, {'POS': 'VERB'}],
    ]

matcher_adj_noun.add("demo", patterns_adj_noun)
matcher_verb_noun.add("demo", patterns_verb_noun)
matcher_adv_noun.add("demo", patterns_adv_noun)

doc_adj_noun = nlp_adj_noun(Condition_3)
doc_adv_noun = nlp_adv_noun(Condition_3)
doc_verb_noun = nlp_verb_noun(Condition_3)


matches_adj_noun = matcher_adj_noun(doc_adj_noun)
matches_verb_noun = matcher_verb_noun(doc_verb_noun)
matches_adv_noun = matcher_adv_noun(doc_adv_noun)

for match_id, start, end in matches_adj_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("ADJ NOUN", span.text)


for match_id, start, end in matches_verb_noun:
    string_id = nlp_adj_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adj_noun[start:end]  # The matched span
    print("VERB NOUN", span.text)

for match_id, start, end in matches_adv_noun:
    string_id = nlp_adv_noun.vocab.strings[match_id]  # Get string representation
    span = doc_adv_noun[start:end]  # The matched span
    print("ADV VERB", span.text)
# Out:
# ADJ NOUN asphalt‐paved parking
# ADJ NOUN fair condition
# ADJ NOUN acceptable drainage
# ADJ NOUN accessible parking
# ADJ NOUN poor condition
# ADJ NOUN widespread alligator
# ADJ NOUN flat grades
# ADJ NOUN select locations
# ADJ NOUN poor condition
# ADJ NOUN widespread alligator
# ADJ NOUN flat grades
# ADJ NOUN large pothole
# ADJ NOUN selective areas
# ADJ NOUN civil engineer
# ADJ NOUN useful information
# ADJ NOUN aesthetic standpoint
# ADJ NOUN accessible route
# VERB NOUN paving surface
# VERB NOUN require crack
# VERB NOUN allow water
# VERB NOUN existing asphalt
# VERB NOUN Add trench
# VERB NOUN creating slope
# VERB NOUN assess grades
# VERB NOUN recommend inlet
# VERB NOUN includes site
# VERB NOUN causing depressions
# ADV VERB reportedly allow
# ADV VERB otherwise interfere
# ADV VERB previously contained
# ADV VERB recently paved

# %%
team1 = pd.concat([df_ds_final, df_ds_cond_final], axis=1)
print(team1)
# Out:
#                                    0                             0
# 0           ADJ NOUN ongoing issues,         VERB NOUN move water,
# 1        ADJ NOUN adequate drainage,     VERB NOUN standing water,
# 2         ADJ NOUN narrow landscape,  VERB NOUN accelerated aging,
# 3               ADJ NOUN south side,          ADV NOUN water away,
# 4     ADJ NOUN municipal stormwater,
# 5   ADJ NOUN official documentation,                           NaN
# 6            ADJ NOUN north portion,                           NaN
# 7         ADJ NOUN northeast corner,                           NaN
# 8        VERB NOUN mitigate surface,                           NaN
# 9            VERB NOUN loading dock,                           NaN
# 10          VERB NOUN paved parking,                           NaN
# 11          ADV NOUN site generally,                           NaN
# 12                                                             NaN

# %%
team2 = pd.concat([df_TC_Des_final, df_TC_cond_final], axis=1)
print(team2)
# Out:
#                               0                                0
# 0    ADJ NOUN Vehicular access,       ADJ NOUN Vehicular access,
# 1    ADJ NOUN northeast corner,         ADJ NOUN public streets,
# 2          VERB NOUN cut leads,  ADJ NOUN vehicular circulation,
# 3      VERB NOUN paved parking,
# 4  VERB NOUN east‐side parking,                              NaN
# 5                                                            NaN

# %%
team3 = pd.concat([df_Park_Des_final, df_SW_Cond_final], axis=1)
print(team3)
# Out:
#                                  0                                 0
# 0       ADJ NOUN distinct surface,   ADJ NOUN asphalt‐paved parking,
# 1              ADJ NOUN south end,          ADJ NOUN fair condition,
# 2          ADJ NOUN main entrance,     ADJ NOUN acceptable drainage,
# 3     ADJ NOUN accessible parking,      ADJ NOUN accessible parking,
# 4           ADJ NOUN recent visit,          ADJ NOUN poor condition,
# 5         ADJ NOUN second surface,    ADJ NOUN widespread alligator,
# 6      ADJ NOUN accessible spaces,             ADJ NOUN flat grades,
# 7          ADJ NOUN third surface,        ADJ NOUN select locations,
# 8      ADJ NOUN accessible spaces,          ADJ NOUN poor condition,
# 9         VERB NOUN paved parking,    ADJ NOUN widespread alligator,
# 10    VERB NOUN asphalt‐paved lot,             ADJ NOUN flat grades,
# 11   VERB NOUN asphalt‐paved area,           ADJ NOUN large pothole,
# 12    VERB NOUN dedicated loading,         ADJ NOUN selective areas,
# ...

# %%
final_team = pd.concat([team1, team2], axis=1)
final_team1 = pd.concat([final_team, team3], axis=1, ignore_index=True)
df = final_team1.fillna('')
print(final_team1)
print(df)
#team.columns = ['Description', 'Condition', 'Description(TC)']
# Out:
#                                    0                             1  \
# 0           ADJ NOUN ongoing issues,         VERB NOUN move water,
# 1        ADJ NOUN adequate drainage,     VERB NOUN standing water,
# 2         ADJ NOUN narrow landscape,  VERB NOUN accelerated aging,
# 3               ADJ NOUN south side,          ADV NOUN water away,
# 4     ADJ NOUN municipal stormwater,
# 5   ADJ NOUN official documentation,                           NaN
# 6            ADJ NOUN north portion,                           NaN
# 7         ADJ NOUN northeast corner,                           NaN
# 8        VERB NOUN mitigate surface,                           NaN
# 9            VERB NOUN loading dock,                           NaN
# 10          VERB NOUN paved parking,                           NaN
# 11          ADV NOUN site generally,                           NaN
# 12                                                             NaN
# ...
